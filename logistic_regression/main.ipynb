# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(x=df['age'],y=df['bought_insurance'], marker='+')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(df[['age']], df['bought_insurance'], train_size=0.9)

# %%
X_test
# Out:
#    age
# 0   22
# 5   56
# 9   61

# %%
X_train
# Out:
#     age
# 25   54
# 10   18
# 19   18
# 14   49
# 18   19
# 4    46
# 20   21
# 17   58
# 22   40
# 7    60
# 24   50
# 15   55
# 1    25
# 2    47
# 21   26
# 26   23
# 13   29
# 12   27
# 3    52
# 8    62
# 16   25
# 6    55
# 23   45
# 11   28

# %%
from sklearn import linear_model

# %%
model = linear_model.LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1])

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
df_sorted = df.sort_values(by='age')

plt.scatter(x=df['age'], y=df['bought_insurance'], marker='+', label='Actual')
plt.plot(df_sorted['age'], model.predict(df_sorted[['age']]), color='red', label='Prediction')
plt.xlabel('Age')
plt.ylabel('Bought Insurance')
plt.legend()
plt.show()

# %%
model.predict_proba(X_test)
# Out:
# array([[0.89575859, 0.10424141],
#        [0.10278705, 0.89721295],
#        [0.05723916, 0.94276084]])

# %%
model.predict([[25]])
# Out:
# /home/arjunbector/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
